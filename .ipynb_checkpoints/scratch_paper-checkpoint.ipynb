# %%
import requests
import uuid
import json
import pandas as pd
import datetime
from time import sleep

# %%
device_id = str(uuid.uuid4())

# %%
r = requests.post("https://api.bird.co/user/login", 
                  json={"email": "john.hayes.21@gmail.com"}, 
                  headers={"device-id": device_id, 'platform': 'ios',  'content-type': 'application/json'})
print(r.status_code, r.reason)
# Out:
# 200 OK

# %%
try:
    token = r.json()['token']
    print('there is a token')
except:
    print('no token')
# Out:
# there is a token

# %%
token_prime = r.json()
token_prime
# Out:
# {'id': '5ccb0bcd-85e2-497f-a935-4449b94dde85',
#  'token': 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJBVVRIIiwidXNlcl9pZCI6IjMzNTE1NmJiLTE2ZDYtNDMyOS1hYWI2LTBhMTM0Y2RkMzlkMSIsImRldmljZV9pZCI6ImM4MzZlODQxLTBiY2ItNGRlNi05YzI0LTNhZDI4NzBkMTcyYyIsImV4cCI6MTU3Mjk4ODExN30.6shmJCU6V6TIjLtalZltEgveUnzJ1a4ZlP7_GNaEKRM'}

# %% [markdown]
# GET-Request to https://api.bird.co/bird/nearby?latitude=37.77184&longitude=-122.40910&radius=1000 And set the following headers:
#
# Authorization: Bird <TOKEN> – Use the token you got from Auth-Request.
# Device-id: <GUID> – You can reuse the GUID from Auth-Request, but don't have to
# App-Version: 3.0.5
# Location: {"latitude":37.77249,"longitude":-122.40910,"altitude":500,"accuracy":100,"speed":-1,"heading":-1} – Yes this is JSON in a header ;) – You should use the same data like from the get Request Params.
# The Result looks like this: {"birds":[{"id":"1486a00c-fd73-4370-9250-782f5c60ee2d","code":"6JLE","location":{"latitude":37.77216,"longitude":-122.409485},"battery_level":89}, ... ]}

# %%
g = requests.get(url= 'https://api.bird.co/bird/nearby?latitude=37.8044&longitude=-122.2711&radius=500',
                headers= {'authorization': 'Bird eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJBVVRIIiwidXNlcl9pZCI6ImJjNzA2NzRhLWQwZGEtNDc3Zi05MmY3LWFjYTljMWQwYWUwYyIsImRldmljZV9pZCI6IjA1Mzc3NzI2LTZjMDYtM2FjZS04MzNmLTIxNzU2OGQ5OWQxNyIsImV4cCI6MTU2MTQ2NzcxNn0.vjNO4YygrykAKdscsmfdnZIBTGtJFUfrwyY3xj287lU', 'device-id':device_id, 'app-version':'3.0.5', 'location': '{"latitude":37.8044,"longitude":-122.2711}'}
                )

# %%
g.json()['birds']
# Out:
# [{'id': '4227025a-5485-4fad-8106-42789649da3d',
#   'location': {'latitude': 37.803954999999995,
#    'longitude': -122.27087333333333},
#   'code': '',
#   'captive': False,
#   'battery_level': 93},
#  {'id': 'bb02ca32-fc9e-43e5-a883-2e650905feb8',
#   'location': {'latitude': 37.804676666666666,
#    'longitude': -122.27164499999999},
#   'code': '',
#   'captive': False,
#   'battery_level': 35},
#  {'id': '60890888-ca29-4a3e-bd98-4ce763b004ef',
#   'location': {'latitude': 37.804703333333336,
#    'longitude': -122.27055333333334},
#   'code': '',
#   'captive': False,
#   'battery_level': 94},
#  {'id': '4a463e7d-f6cc-4bee-833d-b647ba1d7f06',
#   'location': {'latitude': 37.8041752, 'longitude': -122.2718534},
#   'code': '',
#   'captive': False,
#   'battery_level': 67},
#  {'id': '0482e133-2502-428f-9867-1a6e39c41255',
#   'location': {'latitude': 37.80475166666667,
#    'longitude': -122.27178166666666},
#   'code': '',
#   'captive': False,
#   'battery_level': 65},
# ...

# %%
token_bird = 'Bird ' + token_prime

# %%
token2 = 'Bird ' + token

# %%
g = requests.get(url= 'https://api.bird.co/bird/nearby?latitude=37.8044&longitude=-122.2711&radius=500',
                headers= {'authorization': token_bird, 'device-id':device_id, 'app-version':'3.0.5', 'location': '{"latitude":37.8044,"longitude":-122.2711}'}
                )

# %%
g.json()
# Out:
# {'birds': [{'id': 'efa1c2b0-4acf-4c82-a4df-ca39623e9c9f',
#    'location': {'latitude': 37.804386666666666,
#     'longitude': -122.27143833333334},
#    'code': '',
#    'captive': False,
#    'battery_level': 97},
#   {'id': 'c537a2cb-7517-4045-91d3-0b66d61ea9dc',
#    'location': {'latitude': 37.804141666666666, 'longitude': -122.27127},
#    'code': '',
#    'captive': False,
#    'battery_level': 93},
#   {'id': '60890888-ca29-4a3e-bd98-4ce763b004ef',
#    'location': {'latitude': 37.80473666666667,
#     'longitude': -122.27091999999999},
#    'code': '',
#    'captive': False,
#    'battery_level': 94},
#   {'id': '0482e133-2502-428f-9867-1a6e39c41255',
#    'location': {'latitude': 37.804896666666664,
#     'longitude': -122.27145333333334},
#    'code': '',
#    'captive': False,
#    'battery_level': 64},
#   {'id': 'bb02ca32-fc9e-43e5-a883-2e650905feb8',
#    'location': {'latitude': 37.804721666666666,
#     'longitude': -122.27174333333332},
#    'code': '',
# ...

# %%
time_stamp = g.json()

# %%
time_stamp['birds'][0]['id']
# Out:
# 'efa1c2b0-4acf-4c82-a4df-ca39623e9c9f'

# %%
time_stamp['birds'][0]['id'] + ' TIME'
# Out:
# 'efa1c2b0-4acf-4c82-a4df-ca39623e9c9f TIME'

# %%
time_stamp['birds'][0]['unique'] = time_stamp['birds'][0]['id'] + ' ' + str(datetime.datetime.now())
time_stamp['birds'][0]['date_time'] = str(datetime.datetime.now())

# %%
for i in range(len(time_stamp['birds'])):
    time_stamp['birds'][i]['unique'] = time_stamp['birds'][i]['id'] + ' ' + str(datetime.datetime.now())
    time_stamp['birds'][i]['date_time'] = str(datetime.datetime.now())

# %%
time_stamp
# Out:
# {'birds': [{'id': 'efa1c2b0-4acf-4c82-a4df-ca39623e9c9f',
#    'location': {'latitude': 37.804386666666666,
#     'longitude': -122.27143833333334},
#    'code': '',
#    'captive': False,
#    'battery_level': 97,
#    'unique': 'efa1c2b0-4acf-4c82-a4df-ca39623e9c9f 2018-11-05 17:16:45.070672',
#    'date_time': '2018-11-05 17:16:45.070695'},
#   {'id': 'c537a2cb-7517-4045-91d3-0b66d61ea9dc',
#    'location': {'latitude': 37.804141666666666, 'longitude': -122.27127},
#    'code': '',
#    'captive': False,
#    'battery_level': 93,
#    'unique': 'c537a2cb-7517-4045-91d3-0b66d61ea9dc 2018-11-05 17:16:45.070704',
#    'date_time': '2018-11-05 17:16:45.070713'},
#   {'id': '60890888-ca29-4a3e-bd98-4ce763b004ef',
#    'location': {'latitude': 37.80473666666667,
#     'longitude': -122.27091999999999},
#    'code': '',
#    'captive': False,
#    'battery_level': 94,
#    'unique': '60890888-ca29-4a3e-bd98-4ce763b004ef 2018-11-05 17:16:45.070722',
# ...

# %%
import boto3

dynamo = boto3.resource('dynamodb')

table = dynamo.Table('Bird_Scooter_Data')

table.item_count

print(table.creation_date_time)
# Out:
# 2018-11-05 17:22:32.418000-08:00

# %%
# recursively delete empty strings
def del_empty(d):
    """
    Delete keys with the value ``None`` in a dictionary, recursively.

    This alters the input so you may wish to ``copy`` the dict first.
    """
    # For Python 3, write `list(d.items())`; `d.items()` won't work
    # For Python 2, write `d.items()`; `d.iteritems()` won't work
    for key, value in list(d.items()):
        if value == '':
            del d[key]
        elif isinstance(value, dict):
            del_empty(value)
    return d  # For convenience

# %%
# convert floats to string
for i in range(len(time_stamp['birds'])):
    json_str = json.dumps(time_stamp['birds'][i])
    item = json.loads(json_str, parse_float=str)

# %%
for i in range(len(time_stamp['birds'])):
    json_str = json.dumps(time_stamp['birds'][i])
    item = json.loads(json_str, parse_float=str)
    table.put_item(
       Item=del_empty(item)
    )
    print (item)
# Out:
# {'id': 'efa1c2b0-4acf-4c82-a4df-ca39623e9c9f', 'location': {'latitude': '37.804386666666666', 'longitude': '-122.27143833333334'}, 'captive': False, 'battery_level': 97, 'unique': 'efa1c2b0-4acf-4c82-a4df-ca39623e9c9f 2018-11-05 17:16:45.070672', 'date_time': '2018-11-05 17:16:45.070695'}
# {'id': 'c537a2cb-7517-4045-91d3-0b66d61ea9dc', 'location': {'latitude': '37.804141666666666', 'longitude': '-122.27127'}, 'captive': False, 'battery_level': 93, 'unique': 'c537a2cb-7517-4045-91d3-0b66d61ea9dc 2018-11-05 17:16:45.070704', 'date_time': '2018-11-05 17:16:45.070713'}
# {'id': '60890888-ca29-4a3e-bd98-4ce763b004ef', 'location': {'latitude': '37.80473666666667', 'longitude': '-122.27091999999999'}, 'captive': False, 'battery_level': 94, 'unique': '60890888-ca29-4a3e-bd98-4ce763b004ef 2018-11-05 17:16:45.070722', 'date_time': '2018-11-05 17:16:45.070730'}
# ...
